# %% [markdown]
# <a href="https://colab.research.google.com/github/4hqld/DMU-TEST/blob/main/%EB%AF%B8%EC%85%982%5D_Python_Code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = '황현빈'
print(f'제 이름은 {name} 입니다.')
# Out:
# 제 이름은 황현빈 입니다.
